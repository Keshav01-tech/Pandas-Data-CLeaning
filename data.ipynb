# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("freelancer_earnings_bd.csv")
df.head()
# Out:
#    Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0              1    Web Development         Fiverr         Beginner
# 1              2    App Development         Fiverr         Beginner
# 2              3    Web Development         Fiverr         Beginner
# 3              4         Data Entry  PeoplePerHour     Intermediate
# 4              5  Digital Marketing         Upwork           Expert
#
#   Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 0          Asia  Mobile Banking            180          1620        95.79
# 1     Australia  Mobile Banking            218          9078        86.38
# 2            UK          Crypto             27          3455        85.17
# 3          Asia   Bank Transfer             17          5577        14.37
# 4          Asia          Crypto            245          5898        99.37
#
#    Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Freelancer_ID      1950 non-null   int64
#  1   Job_Category       1950 non-null   object
#  2   Platform           1950 non-null   object
#  3   Experience_Level   1950 non-null   object
#  4   Client_Region      1950 non-null   object
#  5   Payment_Method     1950 non-null   object
#  6   Job_Completed      1950 non-null   int64
#  7   Earnings_USD       1950 non-null   int64
#  8   Hourly_Rate        1950 non-null   float64
#  9   Job_Success_Rate   1950 non-null   float64
#  10  Client_Rating      1950 non-null   float64
#  11  Job_Duration_Days  1950 non-null   int64
#  12  Project_Type       1950 non-null   object
#  13  Rehire_Rate        1950 non-null   float64
#  14  Marketing_Spend    1950 non-null   int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
df["Platform"].value_counts()
# Out:
# Platform
# Upwork           420
# Toptal           395
# Fiverr           391
# Freelancer       386
# PeoplePerHour    358
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0              1    Web Development         Fiverr         Beginner
# 1              2    App Development         Fiverr         Beginner
# 2              3    Web Development         Fiverr         Beginner
# 3              4         Data Entry  PeoplePerHour     Intermediate
# 4              5  Digital Marketing         Upwork           Expert
#
#   Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 0          Asia  Mobile Banking            180          1620        95.79
# 1     Australia  Mobile Banking            218          9078        86.38
# 2            UK          Crypto             27          3455        85.17
# 3          Asia   Bank Transfer             17          5577        14.37
# 4          Asia          Crypto            245          5898        99.37
#
#    Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Freelancer_ID      1950 non-null   int64
#  1   Job_Category       1950 non-null   object
#  2   Platform           1950 non-null   object
#  3   Experience_Level   1950 non-null   object
#  4   Client_Region      1950 non-null   object
#  5   Payment_Method     1950 non-null   object
#  6   Job_Completed      1950 non-null   int64
#  7   Earnings_USD       1950 non-null   int64
#  8   Hourly_Rate        1950 non-null   float64
#  9   Job_Success_Rate   1950 non-null   float64
#  10  Client_Rating      1950 non-null   float64
#  11  Job_Duration_Days  1950 non-null   int64
#  12  Project_Type       1950 non-null   object
#  13  Rehire_Rate        1950 non-null   float64
#  14  Marketing_Spend    1950 non-null   int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
df["Platform"].value_counts()
# Out:
# Platform
# Upwork           420
# Toptal           395
# Fiverr           391
# Freelancer       386
# PeoplePerHour    358
# Name: count, dtype: int64

# %%
df["Platform"] =df["Platform"].map({"Upwork":0 ,"Toptal":1 ,"Fiverr":2 ,"Freelancer":3 ,"PeoplePerHour":4})

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category  Platform Experience_Level Client_Region  \
# 0              1    Web Development         2         Beginner          Asia
# 1              2    App Development         2         Beginner     Australia
# 2              3    Web Development         2         Beginner            UK
# 3              4         Data Entry         4     Intermediate          Asia
# 4              5  Digital Marketing         0           Expert          Asia
#
#    Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  Job_Success_Rate  \
# 0  Mobile Banking            180          1620        95.79             68.73
# 1  Mobile Banking            218          9078        86.38             97.54
# 2          Crypto             27          3455        85.17             86.60
# 3   Bank Transfer             17          5577        14.37             79.93
# 4          Crypto            245          5898        99.37             57.80
#
# ...

# %%
df["Experience_Level"].value_counts()
# Out:
# Experience_Level
# Beginner        668
# Intermediate    641
# Expert          641
# Name: count, dtype: int64

# %%
df['Experience_Level'] = df["Experience_Level"].map({"Beginner":0 ,"Intermediate":1 ,"Expert":2})

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category  Platform  Experience_Level Client_Region  \
# 0              1    Web Development         2                 0          Asia
# 1              2    App Development         2                 0     Australia
# 2              3    Web Development         2                 0            UK
# 3              4         Data Entry         4                 1          Asia
# 4              5  Digital Marketing         0                 2          Asia
#
#    Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  Job_Success_Rate  \
# 0  Mobile Banking            180          1620        95.79             68.73
# 1  Mobile Banking            218          9078        86.38             97.54
# 2          Crypto             27          3455        85.17             86.60
# 3   Bank Transfer             17          5577        14.37             79.93
# 4          Crypto            245          5898        99.37             57.80
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Freelancer_ID      1950 non-null   int64
#  1   Job_Category       1950 non-null   object
#  2   Platform           1950 non-null   int64
#  3   Experience_Level   1950 non-null   int64
#  4   Client_Region      1950 non-null   object
#  5   Payment_Method     1950 non-null   object
#  6   Job_Completed      1950 non-null   int64
#  7   Earnings_USD       1950 non-null   int64
#  8   Hourly_Rate        1950 non-null   float64
#  9   Job_Success_Rate   1950 non-null   float64
#  10  Client_Rating      1950 non-null   float64
#  11  Job_Duration_Days  1950 non-null   int64
#  12  Project_Type       1950 non-null   object
#  13  Rehire_Rate        1950 non-null   float64
#  14  Marketing_Spend    1950 non-null   int64
# dtypes: float64(4), int64(7), object(4)
# ...

# %%
df["Rehire_Rate"] = df["Rehire_Rate"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Freelancer_ID      1950 non-null   int64
#  1   Job_Category       1950 non-null   object
#  2   Platform           1950 non-null   int64
#  3   Experience_Level   1950 non-null   int64
#  4   Client_Region      1950 non-null   object
#  5   Payment_Method     1950 non-null   object
#  6   Job_Completed      1950 non-null   int64
#  7   Earnings_USD       1950 non-null   int64
#  8   Hourly_Rate        1950 non-null   float64
#  9   Job_Success_Rate   1950 non-null   float64
#  10  Client_Rating      1950 non-null   float64
#  11  Job_Duration_Days  1950 non-null   int64
#  12  Project_Type       1950 non-null   object
#  13  Rehire_Rate        1950 non-null   int32
#  14  Marketing_Spend    1950 non-null   int64
# dtypes: float64(3), int32(1), int64(7), object(4)
# ...

# %%
df["Project_Type"].value_counts()
# Out:
# Project_Type
# Fixed     997
# Hourly    953
# Name: count, dtype: int64

# %%
df["Project_Type"]= df["Project_Type"].map({"Fixed":0 ,"Hourly":1})

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category  Platform  Experience_Level Client_Region  \
# 0              1    Web Development         2                 0          Asia
# 1              2    App Development         2                 0     Australia
# 2              3    Web Development         2                 0            UK
# 3              4         Data Entry         4                 1          Asia
# 4              5  Digital Marketing         0                 2          Asia
#
#    Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  Job_Success_Rate  \
# 0  Mobile Banking            180          1620        95.79             68.73
# 1  Mobile Banking            218          9078        86.38             97.54
# 2          Crypto             27          3455        85.17             86.60
# 3   Bank Transfer             17          5577        14.37             79.93
# 4          Crypto            245          5898        99.37             57.80
#
# ...

# %%
df["Client_Rating"] = df["Client_Rating"].astype(int)

# %%
df["Job_Success_Rate"] = df["Job_Success_Rate"].astype(int)

# %%
df["job_hour"]  = df["Hourly_Rate"].astype(int)
df["job_minute"] = (df["Hourly_Rate"] % 1).round(2)

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category  Platform  Experience_Level Client_Region  \
# 0              1    Web Development         2                 0          Asia
# 1              2    App Development         2                 0     Australia
# 2              3    Web Development         2                 0            UK
# 3              4         Data Entry         4                 1          Asia
# 4              5  Digital Marketing         0                 2          Asia
#
#    Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  Job_Success_Rate  \
# 0  Mobile Banking            180          1620        95.79                68
# 1  Mobile Banking            218          9078        86.38                97
# 2          Crypto             27          3455        85.17                86
# 3   Bank Transfer             17          5577        14.37                79
# 4          Crypto            245          5898        99.37                57
#
# ...

# %%
df.drop("job_minute",inplace=True,axis=1)

# %%
df.head()
# Out:
#    Freelancer_ID       Job_Category  Platform  Experience_Level Client_Region  \
# 0              1    Web Development         2                 0          Asia
# 1              2    App Development         2                 0     Australia
# 2              3    Web Development         2                 0            UK
# 3              4         Data Entry         4                 1          Asia
# 4              5  Digital Marketing         0                 2          Asia
#
#    Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  Job_Success_Rate  \
# 0  Mobile Banking            180          1620        95.79                68
# 1  Mobile Banking            218          9078        86.38                97
# 2          Crypto             27          3455        85.17                86
# 3   Bank Transfer             17          5577        14.37                79
# 4          Crypto            245          5898        99.37                57
#
# ...

# %%
df.drop("Hourly_Rate",inplace=True, axis=1)

# %%
df.drop("Job_Category",inplace=True, axis=1)

# %%
df["Client_Region"].value_counts()
# Out:
# Client_Region
# Australia      298
# USA            292
# Middle East    291
# Asia           281
# UK             280
# Europe         262
# Canada         246
# Name: count, dtype: int64

# %%
df["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Crypto            514
# Bank Transfer     494
# Mobile Banking    476
# PayPal            466
# Name: count, dtype: int64

# %%
df["Payment_Method"]=df["Payment_Method"].map({"Crypto":0 ,"BBank Transfera":1,"Mobile Banking":2,"PayPal":3})

# %%
df.head()
# Out:
#    Freelancer_ID  Platform  Experience_Level Client_Region  Payment_Method  \
# 0              1         2                 0          Asia             2.0
# 1              2         2                 0     Australia             2.0
# 2              3         2                 0            UK             0.0
# 3              4         4                 1          Asia             NaN
# 4              5         0                 2          Asia             0.0
#
#    Job_Completed  Earnings_USD  Job_Success_Rate  Client_Rating  \
# 0            180          1620                68              3
# 1            218          9078                97              3
# 2             27          3455                86              4
# 3             17          5577                79              4
# 4            245          5898                57              5
#
#    Job_Duration_Days  Project_Type  Rehire_Rate  Marketing_Spend  job_hour
# ...

# %%
df["Client_Region"].value_counts()
# Out:
# Client_Region
# Australia      298
# USA            292
# Middle East    291
# Asia           281
# UK             280
# Europe         262
# Canada         246
# Name: count, dtype: int64

# %%
df.drop("Client_Region" , inplace=True ,axis=1)

# %%
df.head()
# Out:
#    Freelancer_ID  Platform  Experience_Level  Payment_Method  Job_Completed  \
# 0              1         2                 0             2.0            180
# 1              2         2                 0             2.0            218
# 2              3         2                 0             0.0             27
# 3              4         4                 1             NaN             17
# 4              5         0                 2             0.0            245
#
#    Earnings_USD  Job_Success_Rate  Client_Rating  Job_Duration_Days  \
# 0          1620                68              3                  1
# 1          9078                97              3                 54
# 2          3455                86              4                 46
# 3          5577                79              4                 41
# 4          5898                57              5                 41
#
#    Project_Type  Rehire_Rate  Marketing_Spend  job_hour
# ...

# %%
df_test = df[df["job_hour"].isnull()]

# %%
df_train = df

# %%
X = df_train.drop('job_hour',axis=1)

# %%
X.head(4)
# Out:
#    Freelancer_ID  Platform  Experience_Level  Payment_Method  Job_Completed  \
# 0              1         2                 0             2.0            180
# 1              2         2                 0             2.0            218
# 2              3         2                 0             0.0             27
# 3              4         4                 1             NaN             17
#
#    Earnings_USD  Job_Success_Rate  Client_Rating  Job_Duration_Days  \
# 0          1620                68              3                  1
# 1          9078                97              3                 54
# 2          3455                86              4                 46
# 3          5577                79              4                 41
#
#    Project_Type  Rehire_Rate  Marketing_Spend
# 0             0           40               53
# 1             0           36              486
# 2             1           74              489
# 3             1           27               67

# %%
Y =df_train['job_hour']

# %%
Y
# Out:
# 0       95
# 1       86
# 2       85
# 3       14
# 4       99
#         ..
# 1945    22
# 1946    77
# 1947    24
# 1948    71
# 1949    22
# Name: job_hour, Length: 1950, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)

# %%
X_train.to_numpy()
# Out:
# array([[1.331e+03, 0.000e+00, 0.000e+00, ..., 0.000e+00, 5.600e+01,
#         2.850e+02],
#        [8.660e+02, 0.000e+00, 0.000e+00, ..., 1.000e+00, 7.900e+01,
#         4.700e+01],
#        [1.856e+03, 3.000e+00, 1.000e+00, ..., 1.000e+00, 3.600e+01,
#         4.640e+02],
#        ...,
#        [8.610e+02, 0.000e+00, 2.000e+00, ..., 1.000e+00, 4.300e+01,
#         1.280e+02],
#        [1.460e+03, 1.000e+00, 1.000e+00, ..., 0.000e+00, 4.400e+01,
#         2.730e+02],
#        [1.127e+03, 1.000e+00, 0.000e+00, ..., 1.000e+00, 2.800e+01,
#         2.770e+02]])

# %%
X_test.to_numpy()
# Out:
# array([[1.615e+03, 4.000e+00, 0.000e+00, ..., 1.000e+00, 1.700e+01,
#         3.710e+02],
#        [1.406e+03, 3.000e+00, 1.000e+00, ..., 1.000e+00, 4.700e+01,
#         4.620e+02],
#        [9.750e+02, 0.000e+00, 2.000e+00, ..., 1.000e+00, 3.000e+01,
#         3.480e+02],
#        ...,
#        [2.880e+02, 3.000e+00, 2.000e+00, ..., 1.000e+00, 5.000e+01,
#         1.280e+02],
#        [1.418e+03, 4.000e+00, 1.000e+00, ..., 0.000e+00, 7.700e+01,
#         4.290e+02],
#        [1.936e+03, 2.000e+00, 0.000e+00, ..., 0.000e+00, 5.100e+01,
#         1.390e+02]])
