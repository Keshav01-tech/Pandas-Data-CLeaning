# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snc 
# %matplotlib inline

# %%
df_test = pd.read_excel('Data_Train.xlsx')
df_test.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_train = pd.read_excel('Test_set.xlsx')
df_train.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df =pd.merge(df_test ,df_train , how ='left' )
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
final_df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10692     Air Asia       9/04/2019   Kolkata    Banglore
# 10693    Air India      27/04/2019   Kolkata    Banglore
# 10694  Jet Airways      27/04/2019  Banglore       Delhi
# 10695      Vistara      01/03/2019  Banglore   New Delhi
# 10696    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10692              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10693              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10694              BLR → DEL    08:20        11:20       3h    non-stop
# 10695              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10696  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10692         No info   4107
# 10693         No info   4145
# 10694         No info   7229
# 10695         No info  12648
# 10696         No info  11753

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Date_of_Journey  10697 non-null  object
#  2   Source           10697 non-null  object
#  3   Destination      10697 non-null  object
#  4   Route            10696 non-null  object
#  5   Dep_Time         10697 non-null  object
#  6   Arrival_Time     10697 non-null  object
#  7   Duration         10697 non-null  object
#  8   Total_Stops      10696 non-null  object
#  9   Additional_Info  10697 non-null  object
#  10  Price            10697 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 919.4+ KB

# %%
final_df['Date'] =final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month'] =final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year'] =final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
final_df['Date']=final_df['Date'].astype(int)

# %%
final_df['Month'] = final_df['Month'].astype(int)

# %%
final_df['Year']=final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Date_of_Journey  10697 non-null  object
#  2   Source           10697 non-null  object
#  3   Destination      10697 non-null  object
#  4   Route            10696 non-null  object
#  5   Dep_Time         10697 non-null  object
#  6   Arrival_Time     10697 non-null  object
#  7   Duration         10697 non-null  object
#  8   Total_Stops      10696 non-null  object
#  9   Additional_Info  10697 non-null  object
#  10  Price            10697 non-null  int64
#  11  Date             10697 non-null  int64
#  12  Month            10697 non-null  int64
#  13  Year             10697 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.1+ MB

# %%
final_df['Date_of_Journey'] = final_df.drop('Date_of_Journey', axis=1 , inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3
# 1         13:15   7h 25m     2 stops         No info   7662     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6
# 3         23:30   5h 25m      1 stop         No info   6218    12      5
# 4         21:35   4h 45m      1 stop         No info  13302     1      3
#
#    Year Date_of_Journey
# 0  2019            None
# 1  2019            None
# 2  2019            None
# ...

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
final_df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Date', 'Month',
#        'Year'],
#       dtype='object')

# %%
final_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10692    22:25
# 10693    23:20
# 10694    11:20
# 10695    14:10
# 10696    19:15
# Name: Arrival_Time, Length: 10697, dtype: object

# %%
final_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# dtype: int64

# %%
final_df['Price'].value_counts()
# Out:
# Price
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 6373       1
# 13143      1
# 3527       1
# 3673       1
# 57209      1
# Name: count, Length: 1870, dtype: int64

# %%
 final_df['Arrival_Time'] =final_df['Arrival_Time'].str.split(' ').str[0]

# %%
final_df['Arival_hour'] = final_df['Arrival_Time'].str.split(':').str[0]

# %%
final_df['Arival_min'] = final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019
#
#   Arival_hour Arival_min
# 0          01         10
# 1          13         15
# ...

# %%
final_df['Arival_hour'] = final_df['Arival_hour'].astype(int)
final_df['Arival_min'] = final_df['Arival_hour'].astype(int)

# %%
final_df.drop('Arrival_Time' , axis=1 ,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arival_hour  \
# 0    non-stop         No info   3897    24      3  2019            1
# 1     2 stops         No info   7662     1      5  2019           13
# 2     2 stops         No info  13882     9      6  2019            4
# 3      1 stop         No info   6218    12      5  2019           23
# 4      1 stop         No info  13302     1      3  2019           21
#
#    Arival_min
# 0           1
# 1          13
# 2           4
# 3          23
# ...

# %%
final_df['Dep_Time'] = final_df['Dep_Time'].str.split(':')

# %%
final_df['Dep_hour'] = final_df['Dep_Time'].str[0]

# %%
final_df['Dep_min'] = final_df['Dep_Time'].str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route  Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  [22, 20]
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR  [05, 50]
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  [09, 25]
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR  [18, 05]
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL  [16, 50]
#
#   Duration Total_Stops Additional_Info  Price  Date  Month  Year  Arival_hour  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019            1
# 1   7h 25m     2 stops         No info   7662     1      5  2019           13
# 2      19h     2 stops         No info  13882     9      6  2019            4
# 3   5h 25m      1 stop         No info   6218    12      5  2019           23
# 4   4h 45m      1 stop         No info  13302     1      3  2019           21
#
#    Arival_min Dep_hour Dep_min
# 0           1       22      20
# ...

# %%
final_df.drop('Dep_Time' , inplace=True , axis=1)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arival_hour  \
# 0    non-stop         No info   3897    24      3  2019            1
# 1     2 stops         No info   7662     1      5  2019           13
# 2     2 stops         No info  13882     9      6  2019            4
# 3      1 stop         No info   6218    12      5  2019           23
# 4      1 stop         No info  13302     1      3  2019           21
#
#    Arival_min Dep_hour Dep_min
# 0           1       22      20
# 1          13       05      50
# 2           4       09      25
# ...

# %%
final_df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3494
# 2 stops     1531
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
final_df['Total_Stops'] =final_df['Total_Stops'].map({'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 , '4 stops':4})

# %%
final_df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1.0    5625
# 0.0    3494
# 2.0    1531
# 3.0      45
# 4.0       1
# Name: count, dtype: int64

# %%
final_df['Duration_hour'] = final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info  Price  Date  Month  Year  Arival_hour  \
# 0          0.0         No info   3897    24      3  2019            1
# 1          2.0         No info   7662     1      5  2019           13
# 2          2.0         No info  13882     9      6  2019            4
# 3          1.0         No info   6218    12      5  2019           23
# 4          1.0         No info  13302     1      3  2019           21
#
#    Arival_min Dep_hour Dep_min Duration_hour
# 0           1       22      20             2
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Source           10697 non-null  object
#  2   Destination      10697 non-null  object
#  3   Route            10696 non-null  object
#  4   Duration         10697 non-null  object
#  5   Total_Stops      10696 non-null  float64
#  6   Additional_Info  10697 non-null  object
#  7   Price            10697 non-null  int64
#  8   Date             10697 non-null  int64
#  9   Month            10697 non-null  int64
#  10  Year             10697 non-null  int64
#  11  Arival_hour      10697 non-null  int64
#  12  Arival_min       10697 non-null  int64
#  13  Dep_hour         10697 non-null  object
#  14  Dep_min          10697 non-null  object
#  15  Duration_hour    10697 non-null  object
# dtypes: float64(1), int64(6), object(9)
# ...

# %%
final_df['Duration_hour'].value_counts()
# Out:
# Duration_hour
# 2     2405
# 1      621
# 3      501
# 7      487
# 5      481
# 9      445
# 12     428
# 8      424
# 13     407
# 11     365
# 10     355
# 6      340
# 14     337
# 23     268
# 15     268
# 26     241
# 16     234
# 4      222
# 22     222
# 21     198
# 24     197
# 25     186
# 27     179
# 20     162
# 18     141
# 19     135
# 17     129
# 28      94
# 29      65
# 30      50
# 38      34
# 37      17
# 33      13
# 32       9
# 34       8
# 35       7
# 36       7
# 31       6
# 47       2
# 42       2
# 39       2
# 5m       1
# 41       1
# 40       1
# Name: count, dtype: int64

# %%
final_df['Duration_hour'] = final_df['Duration_hour'].str.replace('m', '', regex=True)

# %%
final_df['Duration_hour'].isnull().sum()
# Out:
# np.int64(0)

# %%
final_df['Duration_hour'].value_counts()
# Out:
# Duration_hour
# 2     2405
# 1      621
# 3      501
# 7      487
# 5      482
# 9      445
# 12     428
# 8      424
# 13     407
# 11     365
# 10     355
# 6      340
# 14     337
# 23     268
# 15     268
# 26     241
# 16     234
# 22     222
# 4      222
# 21     198
# 24     197
# 25     186
# 27     179
# 20     162
# 18     141
# 19     135
# 17     129
# 28      94
# 29      65
# 30      50
# 38      34
# 37      17
# 33      13
# 32       9
# 34       8
# 36       7
# 35       7
# 31       6
# 47       2
# 42       2
# 39       2
# 41       1
# 40       1
# Name: count, dtype: int64

# %%
final_df['Duration_hour'] = final_df['Duration_hour'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Source           10697 non-null  object
#  2   Destination      10697 non-null  object
#  3   Route            10696 non-null  object
#  4   Duration         10697 non-null  object
#  5   Total_Stops      10696 non-null  float64
#  6   Additional_Info  10697 non-null  object
#  7   Price            10697 non-null  int64
#  8   Date             10697 non-null  int64
#  9   Month            10697 non-null  int64
#  10  Year             10697 non-null  int64
#  11  Arival_hour      10697 non-null  int64
#  12  Arival_min       10697 non-null  int64
#  13  Dep_hour         10697 non-null  object
#  14  Dep_min          10697 non-null  object
#  15  Duration_hour    10697 non-null  int64
# dtypes: float64(1), int64(7), object(8)
# ...

# %%
final_df['Dep_hour'] = final_df['Dep_hour'].astype(int)

# %%
final_df['Dep_min'] = final_df['Dep_min'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Source           10697 non-null  object
#  2   Destination      10697 non-null  object
#  3   Route            10696 non-null  object
#  4   Duration         10697 non-null  object
#  5   Total_Stops      10696 non-null  float64
#  6   Additional_Info  10697 non-null  object
#  7   Price            10697 non-null  int64
#  8   Date             10697 non-null  int64
#  9   Month            10697 non-null  int64
#  10  Year             10697 non-null  int64
#  11  Arival_hour      10697 non-null  int64
#  12  Arival_min       10697 non-null  int64
#  13  Dep_hour         10697 non-null  int64
#  14  Dep_min          10697 non-null  int64
#  15  Duration_hour    10697 non-null  int64
# dtypes: float64(1), int64(9), object(6)
# ...

# %%
final_df.drop('Duration' ,inplace=True ,axis=1)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10697 entries, 0 to 10696
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10697 non-null  object
#  1   Source           10697 non-null  object
#  2   Destination      10697 non-null  object
#  3   Route            10696 non-null  object
#  4   Total_Stops      10696 non-null  float64
#  5   Additional_Info  10697 non-null  object
#  6   Price            10697 non-null  int64
#  7   Date             10697 non-null  int64
#  8   Month            10697 non-null  int64
#  9   Year             10697 non-null  int64
#  10  Arival_hour      10697 non-null  int64
#  11  Arival_min       10697 non-null  int64
#  12  Dep_hour         10697 non-null  int64
#  13  Dep_min          10697 non-null  int64
#  14  Duration_hour    10697 non-null  int64
# dtypes: float64(1), int64(9), object(5)
# memory usage: 1.2+ MB

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()

# %%
final_df['Airline'] = labelEncoder.fit_transform(final_df['Airline'])
final_df['Source'] = labelEncoder.fit_transform(final_df['Airline'])
final_df['Destination'] = labelEncoder.fit_transform(final_df['Airline'])
final_df['Additional_Info'] = labelEncoder.fit_transform(final_df['Airline'])

# %%
final_df.shape
# Out:
# (10697, 15)

# %%
final_df.head(2)
# Out:
#    Airline  Source  Destination                  Route  Total_Stops  \
# 0        3       3            3              BLR → DEL          0.0
# 1        1       1            1  CCU → IXR → BBI → BLR          2.0
#
#    Additional_Info  Price  Date  Month  Year  Arival_hour  Arival_min  \
# 0                3   3897    24      3  2019            1           1
# 1                1   7662     1      5  2019           13          13
#
#    Dep_hour  Dep_min  Duration_hour
# 0        22       20              2
# 1         5       50              7

# %%
final_df.drop('Additonal info' , inplace=True , axis=1)
final_df.drop('Additional Info' , inplace=True , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[416], line 1
# ----> 1 final_df.drop('Additonal info' , inplace=True , axis=1)
#       2 final_df.drop('Additional Info' , inplace=True , axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
final_df.head()
# Out:
#    Airline  Source  Destination                  Route  Total_Stops  \
# 0        3       3            3              BLR → DEL          0.0
# 1        1       1            1  CCU → IXR → BBI → BLR          2.0
# 2        4       4            4  DEL → LKO → BOM → COK          2.0
# 3        3       3            3        CCU → NAG → BLR          1.0
# 4        3       3            3        BLR → NAG → DEL          1.0
#
#    Additional_Info  Price  Date  Month  Year  Arival_hour  Arival_min  \
# 0                3   3897    24      3  2019            1           1
# 1                1   7662     1      5  2019           13          13
# 2                4  13882     9      6  2019            4           4
# 3                3   6218    12      5  2019           23          23
# 4                3  13302     1      3  2019           21          21
#
#    Dep_hour  Dep_min  Duration_hour
# 0        22       20              2
# 1         5       50              7
# ...

# %%
final_df.drop('Additional_info' , inplace=True , axis=1)
final_df.drop('Additional Info' , inplace=True , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[419], line 1
# ----> 1 final_df.drop('Additional_info' , inplace=True , axis=1)
#       2 final_df.drop('Additional Info' , inplace=True , axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
final_df.head()
# Out:
#    Airline  Source  Destination                  Route  Total_Stops  \
# 0        3       3            3              BLR → DEL          0.0
# 1        1       1            1  CCU → IXR → BBI → BLR          2.0
# 2        4       4            4  DEL → LKO → BOM → COK          2.0
# 3        3       3            3        CCU → NAG → BLR          1.0
# 4        3       3            3        BLR → NAG → DEL          1.0
#
#    Additional_Info  Price  Date  Month  Year  Arival_hour  Arival_min  \
# 0                3   3897    24      3  2019            1           1
# 1                1   7662     1      5  2019           13          13
# 2                4  13882     9      6  2019            4           4
# 3                3   6218    12      5  2019           23          23
# 4                3  13302     1      3  2019           21          21
#
#    Dep_hour  Dep_min  Duration_hour
# 0        22       20              2
# 1         5       50              7
# ...

# %%
final_df.drop('Route' , inplace=True , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[496], line 1
# ----> 1 final_df.drop('Route' , inplace=True , axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0        3       3            3          0.0                3   3897    24
# 1        1       1            1          2.0                1   7662     1
# 2        4       4            4          2.0                4  13882     9
# 3        3       3            3          1.0                3   6218    12
# 4        3       3            3          1.0                3  13302     1
#
#    Month  Year  Arival_hour  Arival_min  Dep_hour  Dep_min  Duration_hour
# 0      3  2019            1           1        22       20              2
# 1      5  2019           13          13         5       50              7
# 2      6  2019            4           4         9       25             19
# 3      5  2019           23          23        18        5              5
# 4      3  2019           21          21        16       50              4

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0        3       3            3          0.0                3   3897    24
# 1        1       1            1          2.0                1   7662     1
# 2        4       4            4          2.0                4  13882     9
# 3        3       3            3          1.0                3   6218    12
# 4        3       3            3          1.0                3  13302     1
#
#    Month  Year  Arival_hour  Arival_min  Dep_hour  Dep_min  Duration_hour
# 0      3  2019            1           1        22       20              2
# 1      5  2019           13          13         5       50              7
# 2      6  2019            4           4         9       25             19
# 3      5  2019           23          23        18        5              5
# 4      3  2019           21          21        16       50              4

# %%
final_df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            3       3            3          0.0                3   3897
# 1            1       1            1          2.0                1   7662
# 2            4       4            4          2.0                4  13882
# 3            3       3            3          1.0                3   6218
# 4            3       3            3          1.0                3  13302
# ...        ...     ...          ...          ...              ...    ...
# 10692        0       0            0          0.0                0   4107
# 10693        1       1            1          0.0                1   4145
# 10694        4       4            4          0.0                4   7229
# 10695       10      10           10          0.0               10  12648
# 10696        1       1            1          2.0                1  11753
#
#        Date  Month  Year  Arival_hour  Arival_min  Dep_hour  Dep_min  \
# ...

# %%
final_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arival_hour        0
# Arival_min         0
# Dep_hour           0
# Dep_min            0
# Duration_hour      0
# dtype: int64

# %%
df_test = final_df[final_df['Price'].isnull()]

# %%
df_train = final_df

# %%
X = df_train.drop('Price',axis=1)

# %%
X.head(4)
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Date  Month  \
# 0        3       3            3          0.0                3    24      3
# 1        1       1            1          2.0                1     1      5
# 2        4       4            4          2.0                4     9      6
# 3        3       3            3          1.0                3    12      5
#
#    Year  Arival_hour  Arival_min  Dep_hour  Dep_min  Duration_hour
# 0  2019            1           1        22       20              2
# 1  2019           13          13         5       50              7
# 2  2019            4           4         9       25             19
# 3  2019           23          23        18        5              5

# %%
X.shape
# Out:
# (10697, 13)

# %%
Y =df_train['Price']

# %%
Y
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10692     4107
# 10693     4145
# 10694     7229
# 10695    12648
# 10696    11753
# Name: Price, Length: 10697, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)

# %%
X_train.to_numpy()
# Out:
# array([[ 1.,  1.,  1., ..., 10.,  0., 13.],
#        [ 6.,  6.,  6., ...,  4.,  0., 11.],
#        [ 4.,  4.,  4., ..., 19., 50.,  3.],
#        ...,
#        [ 4.,  4.,  4., ..., 19., 35.,  1.],
#        [ 3.,  3.,  3., ...,  0., 40.,  2.],
#        [ 1.,  1.,  1., ..., 20., 30., 11.]], shape=(7166, 13))

# %%
X_test.to_numpy()
# Out:
# array([[ 4.,  4.,  4., ..., 18., 25., 10.],
#        [ 1.,  1.,  1., ...,  6., 10., 26.],
#        [ 3.,  3.,  3., ...,  6., 40., 14.],
#        ...,
#        [ 4.,  4.,  4., ...,  9., 55., 18.],
#        [ 4.,  4.,  4., ...,  2., 55.,  1.],
#        [ 3.,  3.,  3., ..., 17., 15.,  2.]], shape=(3531, 13))
